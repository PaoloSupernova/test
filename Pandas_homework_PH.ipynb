# %% [markdown]
# <h1>Tackling an open problem</h1>
#
# For this homework the idea is to hone our skills on exploring and plotting a dataset. You can either work with the Pokemon dataset that was given or download your own. If you opt to download your own I recommend you use one of the datasets available on kaggle,
#
# https://www.kaggle.com/datasets
#
# As they tend to be found in a clean format and are generally free to use.
#
# Largely, the main objective is learning how to search the internet for new implementations you want to use on your code helping you develop your self-confidence.
#
# There's no right or wrong, pick a dataset you enjoy and try to have some fun.
# If you need, use the notebook from the previous session as a guideline.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
nfl_df = pd.read_csv('Datasets\\nflstats.csv', sep=',')

# %%
print(nfl_df)
# Out:
#      year                  team  wins  losses  win_loss_perc  points  \
# 0    2003  New England Patriots    14       2          0.875     348
# 1    2003        Miami Dolphins    10       6          0.625     311
# 2    2003         Buffalo Bills     6      10          0.375     243
# 3    2003         New York Jets     6      10          0.375     283
# 4    2003      Baltimore Ravens    10       6          0.625     391
# ..    ...                   ...   ...     ...            ...     ...
# 667  2023     Carolina Panthers     2      15          0.118     236
# 668  2023   San Francisco 49ers    12       5          0.706     491
# 669  2023      Los Angeles Rams    10       7          0.588     404
# 670  2023      Seattle Seahawks     9       8          0.529     364
# 671  2023     Arizona Cardinals     4      13          0.235     330
#
#      points_opp  points_diff   mov   g  ...  rush_td  rush_yds_per_att  \
# ...

# %%
nfl_df.head()
# Out:
#    year                  team  wins  losses  win_loss_perc  points  \
# 0  2003  New England Patriots    14       2          0.875     348
# 1  2003        Miami Dolphins    10       6          0.625     311
# 2  2003         Buffalo Bills     6      10          0.375     243
# 3  2003         New York Jets     6      10          0.375     283
# 4  2003      Baltimore Ravens    10       6          0.625     391
#
#    points_opp  points_diff  mov   g  ...  rush_td  rush_yds_per_att  rush_fd  \
# 0         238          110  6.9  16  ...        9               3.4       91
# 1         261           50  3.1  16  ...       14               3.7       99
# 2         279          -36 -2.3  16  ...       13               3.9       96
# 3         299          -16 -1.0  16  ...        8               4.0       78
# 4         281          110  6.9  16  ...       18               4.8      115
#
#    penalties  penalties_yds  pen_fd  score_pct  turnover_pct  exp_pts_tot  \
# ...

# %%
nfl_df.tail()
# Out:
#      year                 team  wins  losses  win_loss_perc  points  \
# 667  2023    Carolina Panthers     2      15          0.118     236
# 668  2023  San Francisco 49ers    12       5          0.706     491
# 669  2023     Los Angeles Rams    10       7          0.588     404
# 670  2023     Seattle Seahawks     9       8          0.529     364
# 671  2023    Arizona Cardinals     4      13          0.235     330
#
#      points_opp  points_diff   mov   g  ...  rush_td  rush_yds_per_att  \
# 667         416         -180 -10.6  17  ...        7               4.0
# 668         298          193  11.4  17  ...       27               4.8
# 669         377           27   1.6  17  ...       18               4.3
# 670         402          -38  -2.2  17  ...       11               4.1
# 671         455         -125  -7.4  17  ...       17               5.0
#
#      rush_fd  penalties  penalties_yds  pen_fd  score_pct  turnover_pct  \
# ...

# %%
nfl_df.describe()
# Out:
#               year        wins      losses  win_loss_perc      points  \
# count   672.000000  672.000000  672.000000     672.000000  672.000000
# mean   2013.000000    8.050595    8.050595       0.500246  358.633929
# std       6.059811    3.093255    3.086020       0.191452   72.092050
# min    2003.000000    0.000000    0.000000       0.000000  168.000000
# 25%    2008.000000    6.000000    6.000000       0.375000  305.000000
# 50%    2013.000000    8.000000    8.000000       0.500000  359.000000
# 75%    2018.000000   10.000000   10.000000       0.625000  406.000000
# max    2023.000000   16.000000   16.000000       1.000000  606.000000
#
#        points_opp  points_diff         mov           g  total_yards  ...  \
# count  672.000000   672.000000  352.000000  672.000000   672.000000  ...
# mean   358.633929     0.000000   -0.001136   16.139881  5463.895833  ...
# std     57.889328   100.684601    6.313288    0.347122   628.209466  ...
# ...

# %%
# Getting only the items that are in the teams column.
nfl_df['team']
# Out:
# 0      New England Patriots
# 1            Miami Dolphins
# 2             Buffalo Bills
# 3             New York Jets
# 4          Baltimore Ravens
#                ...
# 667       Carolina Panthers
# 668     San Francisco 49ers
# 669        Los Angeles Rams
# 670        Seattle Seahawks
# 671       Arizona Cardinals
# Name: team, Length: 672, dtype: object

# %%
# A list of columns can also be selected.
nfl_df[['team','wins','losses','year']]
# Out:
#                      team  wins  losses  year
# 0    New England Patriots    14       2  2003
# 1          Miami Dolphins    10       6  2003
# 2           Buffalo Bills     6      10  2003
# 3           New York Jets     6      10  2003
# 4        Baltimore Ravens    10       6  2003
# ..                    ...   ...     ...   ...
# 667     Carolina Panthers     2      15  2023
# 668   San Francisco 49ers    12       5  2023
# 669      Los Angeles Rams    10       7  2023
# 670      Seattle Seahawks     9       8  2023
# 671     Arizona Cardinals     4      13  2023
#
# [672 rows x 4 columns]

# %%
nfl_df.keys()
# Out:
# Index(['year', 'team', 'wins', 'losses', 'win_loss_perc', 'points',
#        'points_opp', 'points_diff', 'mov', 'g', 'total_yards', 'plays_offense',
#        'yds_per_play_offense', 'turnovers', 'fumbles_lost', 'first_down',
#        'pass_cmp', 'pass_att', 'pass_yds', 'pass_td', 'pass_int',
#        'pass_net_yds_per_att', 'pass_fd', 'rush_att', 'rush_yds', 'rush_td',
#        'rush_yds_per_att', 'rush_fd', 'penalties', 'penalties_yds', 'pen_fd',
#        'score_pct', 'turnover_pct', 'exp_pts_tot', 'ties'],
#       dtype='object')

# %%
nfl_df.columns
# Out:
# Index(['year', 'team', 'wins', 'losses', 'win_loss_perc', 'points',
#        'points_opp', 'points_diff', 'mov', 'g', 'total_yards', 'plays_offense',
#        'yds_per_play_offense', 'turnovers', 'fumbles_lost', 'first_down',
#        'pass_cmp', 'pass_att', 'pass_yds', 'pass_td', 'pass_int',
#        'pass_net_yds_per_att', 'pass_fd', 'rush_att', 'rush_yds', 'rush_td',
#        'rush_yds_per_att', 'rush_fd', 'penalties', 'penalties_yds', 'pen_fd',
#        'score_pct', 'turnover_pct', 'exp_pts_tot', 'ties'],
#       dtype='object')

# %%
# This shows all the unique entries in the dataset for that column.
nfl_df['team'].unique()
# Out:
# array(['New England Patriots', 'Miami Dolphins', 'Buffalo Bills',
#        'New York Jets', 'Baltimore Ravens', 'Cincinnati Bengals',
#        'Pittsburgh Steelers', 'Cleveland Browns', 'Indianapolis Colts',
#        'Tennessee Titans', 'Jacksonville Jaguars', 'Houston Texans',
#        'Kansas City Chiefs', 'Denver Broncos', 'Oakland Raiders',
#        'San Diego Chargers', 'Philadelphia Eagles', 'Dallas Cowboys',
#        'Washington Redskins', 'New York Giants', 'Green Bay Packers',
#        'Minnesota Vikings', 'Chicago Bears', 'Detroit Lions',
#        'Carolina Panthers', 'New Orleans Saints', 'Tampa Bay Buccaneers',
#        'Atlanta Falcons', 'St. Louis Rams', 'Seattle Seahawks',
#        'San Francisco 49ers', 'Arizona Cardinals', 'Los Angeles Rams',
#        'Los Angeles Chargers', 'Las Vegas Raiders',
#        'Washington Football Team', 'Washington Commanders'], dtype=object)

# %%
# This will count how much incidence of a given unique entry is seen on the dataframe.
nfl_df[['team','wins','losses','year']].value_counts()
# Out:
# team                 wins  losses  year
# Arizona Cardinals    3     13      2018    1
# New York Giants      8     8       2009    1
#                      5     11      2018    1
#                      6     10      2004    1
#                                    2014    1
#                                           ..
# Detroit Lions        9     7       2016    1
#                                    2017    1
#                            8       2022    1
#                      10    6       2011    1
# Washington Redskins  10    6       2012    1
# Name: count, Length: 672, dtype: int64

# %%
# Getting the description.
nfl_df.describe()
# Out:
#               year        wins      losses  win_loss_perc      points  \
# count   672.000000  672.000000  672.000000     672.000000  672.000000
# mean   2013.000000    8.050595    8.050595       0.500246  358.633929
# std       6.059811    3.093255    3.086020       0.191452   72.092050
# min    2003.000000    0.000000    0.000000       0.000000  168.000000
# 25%    2008.000000    6.000000    6.000000       0.375000  305.000000
# 50%    2013.000000    8.000000    8.000000       0.500000  359.000000
# 75%    2018.000000   10.000000   10.000000       0.625000  406.000000
# max    2023.000000   16.000000   16.000000       1.000000  606.000000
#
#        points_opp  points_diff         mov           g  total_yards  ...  \
# count  672.000000   672.000000  352.000000  672.000000   672.000000  ...
# mean   358.633929     0.000000   -0.001136   16.139881  5463.895833  ...
# std     57.889328   100.684601    6.313288    0.347122   628.209466  ...
# ...

# %%
nfl_df['points'].describe()
# Out:
# count    672.000000
# mean     358.633929
# std       72.092050
# min      168.000000
# 25%      305.000000
# 50%      359.000000
# 75%      406.000000
# max      606.000000
# Name: points, dtype: float64

# %%
nfl_df.hist()
# Out:
# array([[<Axes: title={'center': 'year'}>,
#         <Axes: title={'center': 'wins'}>,
#         <Axes: title={'center': 'losses'}>,
#         <Axes: title={'center': 'win_loss_perc'}>,
#         <Axes: title={'center': 'points'}>,
#         <Axes: title={'center': 'points_opp'}>],
#        [<Axes: title={'center': 'points_diff'}>,
#         <Axes: title={'center': 'mov'}>, <Axes: title={'center': 'g'}>,
#         <Axes: title={'center': 'total_yards'}>,
#         <Axes: title={'center': 'plays_offense'}>,
#         <Axes: title={'center': 'yds_per_play_offense'}>],
#        [<Axes: title={'center': 'turnovers'}>,
#         <Axes: title={'center': 'fumbles_lost'}>,
#         <Axes: title={'center': 'first_down'}>,
#         <Axes: title={'center': 'pass_cmp'}>,
#         <Axes: title={'center': 'pass_att'}>,
#         <Axes: title={'center': 'pass_yds'}>],
#        [<Axes: title={'center': 'pass_td'}>,
#         <Axes: title={'center': 'pass_int'}>,
# ...

# %%
nfl_df.hist('ties')
# Out:
# array([[<Axes: title={'center': 'ties'}>]], dtype=object)
